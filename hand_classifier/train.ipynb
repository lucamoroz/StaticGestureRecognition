# %%
from hand_cnn import HandCNN

# %%
handCNN = HandCNN()
history = handCNN.train(data_path="../dataset/testdataset/", epochs=2, batch_size=16)
# Out:
# Found 78 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 4/4 [==============================] - ETA: 0s - loss: 57.7969 - accuracy: 0.2258
# Epoch 00001: saving model to models/2020-11-27 17:38:08.816040/checkpoint-model-01-0.19.hdf5
# 4/4 [==============================] - 3s 825ms/step - loss: 57.7969 - accuracy: 0.2258 - val_loss: 3.6019 - val_accuracy: 0.1875
# Epoch 2/2
# 4/4 [==============================] - ETA: 0s - loss: 1.7146 - accuracy: 0.1613
# Epoch 00002: saving model to models/2020-11-27 17:38:08.816040/checkpoint-model-02-0.12.hdf5
# 4/4 [==============================] - 3s 750ms/step - loss: 1.7146 - accuracy: 0.1613 - val_loss: 4.6082 - val_accuracy: 0.1250

# %%
# Show training graph

import matplotlib.pyplot as plt
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
