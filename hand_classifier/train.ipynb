# %%
from hand_cnn import HandCNN

# %%
handCNN = HandCNN(load=False)
history = handCNN.train(data_path="../dataset/testdataset/", epochs=2, batch_size=16)
# Out:
# Found 78 images belonging to 6 classes.
# Found 18 images belonging to 6 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 4/4 [==============================] - ETA: 0s - loss: 63.9832 - accuracy: 0.2188
# Epoch 00001: saving model to models/2020-11-27 17:00:23.615336/checkpoint-model-01-0.19.hdf5
# 4/4 [==============================] - 4s 1s/step - loss: 63.9832 - accuracy: 0.2188 - val_loss: 34.4384 - val_accuracy: 0.1875
# Epoch 2/2
# 4/4 [==============================] - ETA: 0s - loss: 6.3060 - accuracy: 0.2188
# Epoch 00002: saving model to models/2020-11-27 17:00:23.615336/checkpoint-model-02-0.19.hdf5
# 4/4 [==============================] - 38s 9s/step - loss: 6.3060 - accuracy: 0.2188 - val_loss: 14.6111 - val_accuracy: 0.1875

# %%
# Show training graph

import matplotlib.pyplot as plt
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
